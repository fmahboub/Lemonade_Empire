# %%
# Ignore if running locally
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Define menu functions and main game loop
import random
import time
from termcolor import colored
import pandas as pd
import csv
from datetime import date
from IPython.display import clear_output

def mainMenu ():
    command = ""
    while command != "N":
        clear_output(wait=True)
        print ("DAY:"+ str(day)+"\nCASH:$" +str('{:.2f}'.format(round(cash,2))))
        print ("LOCATIONS:"+ str(locations)+"\nLEMONS:"+ str(lemons)+" SUGAR:"+ str('{:.1f}'.format(round(sugar,1)))+"kg"+
               " CUPS:"+ str(cups))
        print ("___________________________")
        print ("_________MAIN MENU_________")
        print ("..................MARKET (M)")
        print ("........DEPARTMENT STORE (D)")
        print ("....................BANK (B)")
        print ("........MARKETING AGENCY (A)")
        print ("...........BEGIN NEW DAY (N)")
        print ("")
        command = (input("ENTER COMMAND HERE: ")).upper()
        while command != "M" and command != "D" and command != "B" and command != "A" and command != "N":
            command = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command == "M":
            marketMenu()
        if command == "D":
            departmentStore()
        if command == "B":
            bankMenu()
        if command == "A":
            marketingAgencyMenu()

def marketMenu ():
    command1 = ""
    global cash
    while command1 != "R":
        clear_output(wait=True)
        time.sleep(.05)
        print ("LEMONS:"+ str(lemons)+"  SUGAR:"+ str('{:.1f}'.format(round(sugar,1)))+
               "kg"+ "  CUPS:"+ str(cups)+ "  CASH:$" +str('{:.2f}'.format(round(cash,2))))
        print ("__________________________")
        print ("__________MARKET__________")
        print (".............LEMON SHOP (L)")
        print (".............SUGAR SHOP (S)")
        print ("..............CUP STORE (C)")
        print ("....RETURN TO MAIN MENU (R)")
        print ("")
        command1 = (input ("ENTER COMMAND HERE: ")).upper()
        while command1 != "L" and command1 != "S" and command1 != "C" and command1 != "R":
            command1 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command1 == "L":
            lemonShop()
        if command1 == "S":
            sugarShop()
        if command1 == "C":
            cupShop()

def marketingAgencyMenu ():
    command2 = ""
    global cash, searchEnginePrice, billboardPrice, radioPrice, socialMediaPrice, marketingEffect
    global radioCampaignDays, searchEngineCampaignDays, socialMediaCampaignDays, billboardCampaignDays
    while command2 != "R":
    # set marketing effects based on ads
        if searchEngineCampaignDays > 0:
            marketingEffect = 10
            if socialMediaCampaignDays > 0:
                marketingEffect = 30
                if radioCampaignDays > 0:
                    marketingEffect = 60
                if billboardCampaignDays > 0:
                    marketingEffect = 70
                    if radioCampaignDays > 0:
                        marketingEffect = 100
            if radioCampaignDays > 0 and socialMediaCampaignDays == 0:
                marketingEffect = 40
                if billboardCampaignDays > 0:
                    marketingEffect = 80
            if billboardCampaignDays > 0 and searchEngineCampaignDays == 0 and radioCampaignDays == 0:
                marketingEffect = 50
        if socialMediaCampaignDays > 0 and searchEngineCampaignDays == 0:
            marketingEffect = 15
            if radioCampaignDays > 0:
                marketingEffect = 45
                if billboardCampaignDays > 0:
                    marketingEffect = 85
            if billboardCampaignDays > 0 and radioCampaignDays == 0:
                marketingEffect = 60
        if radioCampaignDays > 0 and socialMediaCampaignDays == 0 and searchEngineCampaignDays == 0:
            marketingEffect = 25
            if billboardCampaignDays > 0:
                marketingEffect = 65
        if billboardCampaignDays > 0 and radioCampaignDays == 0:
            if socialMediaCampaignDays == 0 and searchEngineCampaignDays == 0:
                marketingEffect = 35
        if billboardCampaignDays > 0 and radioCampaignDays == 0:
            if socialMediaCampaignDays == 0 and searchEngineCampaignDays > 0:
                marketingEffect = 50
        if searchEngineCampaignDays == 0 and socialMediaCampaignDays == 0:
            if radioCampaignDays == 0 and billboardCampaignDays == 0:
                marketingEffect = 0
        spaceCount2 = 17 - int(len(str('{:.1f}'.format(marketingEffect))))
        spaceCount3 = "."*spaceCount2
        clear_output(wait=True)
        time.sleep(.1)
        print ("DAY:"+ str(day)+"\nCASH:$" +str('{:.2f}'.format(round(cash,2))))
        if searchEngineCampaignDays > 0:
            print ("SEARCH ENGINE OPTIMIZATION DAYS LEFT: "+str(searchEngineCampaignDays))
        if socialMediaCampaignDays > 0:
            print ("SOCIAL MEDIA CAMPAIGN DAYS LEFT: "+str(socialMediaCampaignDays))
        if radioCampaignDays > 0:
            print ("RADIO CAMPAIGN DAYS LEFT: "+str(radioCampaignDays))
        if billboardCampaignDays > 0:
            print ("BILLBOARD ADVERTISEMENT DAYS LEFT: "+str(billboardCampaignDays))
        print ("______________________________________________")
        print ("_______________Marketing Agency_______________")
        print ("OVERALL MARKETING EFFECTIVENESS"+spaceCount3+str(marketingEffect)+"%")
        print ("...1 WEEK INTERNET SEARCH OPTIMIZATION: $"+str(searchEnginePrice)+ " (1)")
        print (".....1 WEEK SOCIAL MEDIA ADVERTISEMENT: $"+str(socialMediaPrice)+ " (2)")
        print (".............1 WEEK RADIO AD CAMPAIGN: $"+str(radioPrice)+" (3)")
        print (".......1 WEEK BILLBOARD ADVERTISEMENT: $"+str(billboardPrice)+ " (4)")
        print ("......................RETURN TO MARKET MENU (R)")
        print ("")
        command2 = (input ("ENTER COMMAND HERE: ")).upper()
        while command2 != "1" and command2 != "2" and command2 != "3" and command2 !="4" and command2 != "R":
            command2 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command2 == "1":
            if cash >= searchEnginePrice:
                confirm = input("PLEASE CONFIRM PURCHASE OF SEARCH ENGINE OPTIMIZATION (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    searchEngineCampaignDays +=7
                    cash -= searchEnginePrice
            else:
                print("")        
                print (colored("YOU CAN'T AFFORD THIS PURCHASE!",'red'))
                time.sleep(1)
        if command2 == "2":
            if cash >= socialMediaPrice:
                confirm = input("PLEASE CONFIRM PURCHASE OF SOCIAL MEDIA ADS (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    socialMediaCampaignDays +=7
                    cash -= socialMediaPrice
            else:        
                print("")        
                print (colored("YOU CAN'T AFFORD THIS PURCHASE!", "red"))
                time.sleep(1)
        if command2 == "3":
            if cash >= radioPrice:
                confirm = input("PLEASE CONFIRM PURCHASE OF RADIO CAMPAIGN (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    radioCampaignDays +=7
                    cash -= radioPrice
            else:        
                print("")        
                print (colored("YOU CAN'T AFFORD THIS PURCHASE!",'red'))
                time.sleep(1)
        if command2 == "4":
            if cash >= billboardPrice:
                confirm = input("PLEASE CONFIRM PURCHASE OF BILLBOARD ADVERTISESMENT (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    billboardCampaignDays +=7
                    cash -= billboardPrice
            else:        
                print("")        
                print (colored("YOU CAN'T AFFORD THIS PURCHASE!",'red'))
                time.sleep(1)

def lemonShop ():
    command11 = ""
    global cash, lemons
    while command11 != "R":
        clear_output(wait=True)
        time.sleep(.1)
        print ("LEMONS:"+ str(lemons)+"  SUGAR:"+ str('{:.1f}'.format(round(sugar,1)))+
               "kg"+ "  CUPS:"+ str(cups)+ "  CASH:$" +str('{:.2f}'.format(round(cash,2))))
        print ("________________________________________")
        print ("_______________LEMON SHOP_______________")
        print (".......MARKET PRICE OF 1 LEMON: $"+str('{:.2f}'.format(round(lemPrice,2)))+" (1)")
        print ("......MARKET PRICE OF 5 LEMONS: $"+str('{:.2f}'.format(round(5*lemPrice*.96,2)))+" (2)")
        print ("....MARKET PRICE OF 20 LEMONS: $"+str('{:.2f}'.format(round(20*lemPrice*.93,2)))+" (3)")
        print ("................RETURN TO MARKET MENU (R)")
        print ("")
        command11 = (input ("ENTER COMMAND HERE: ")).upper()
        while command11 != "1" and command11 != "2" and command11 != "3" and command11 != "R":
            command11 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command11 != "R":
            while True:
                try:
                    lemAmount = int(input("PLEASE ENTER # OF UNITS TO PURCHASE: "))
                    if command11 == "1":
                        while lemAmount*lemPrice > cash or lemAmount<0: 
                            while lemAmount*lemPrice > cash: 
                                lemAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while lemAmount < 0:
                                lemAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command11 == "2":
                        while lemAmount*round(5*lemPrice*.96,2) > cash or lemAmount<0: 
                            while lemAmount*round(5*lemPrice*.96,2) > cash:
                                lemAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while lemAmount < 0:
                                lemAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command11 == "3":
                        while lemAmount*round(20*lemPrice*.93,2) > cash or lemAmount<0: 
                            while lemAmount*round(20*lemPrice*.93,2) > cash: 
                                lemAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while lemAmount < 0:
                                lemAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command11 == "1":
                        lemons += lemAmount
                        cash -= lemAmount*lemPrice
                    if command11 == "2":
                        lemons += lemAmount*5
                        cash -= lemAmount*round(5*lemPrice*.96,2)
                    if command11 == "3":
                        lemons += lemAmount*20
                        cash -= lemAmount*round(20*lemPrice*.93,2)
                    break
                except ValueError:
                    print ("PLEASE ENTER INTEGER!")

def sugarShop ():
    command12 = ""
    global cash, sugar 
    while command12 != "R":
        clear_output(wait=True)
        time.sleep(.1)
        print ("LEMONS:"+ str(lemons)+"  SUGAR:"+ str('{:.1f}'.format(round(sugar,2)))+
               "kg"+ "  CUPS:"+ str(cups)+ "  CASH:$" +str('{:.2f}'.format(round(cash,2))))
        print ("________________________________________")
        print ("_______________SUGAR SHOP_______________")
        print (".....MARKET PRICE OF 1kg SUGAR: $"+str('{:.2f}'.format(round(sugPrice,2)))+" (1)")
        print (".....MARKET PRICE OF 5kg SUGAR: $"+str('{:.2f}'.format(round(5*sugPrice*.98,2)))+" (2)")
        print ("...MARKET PRICE OF 20kg SUGAR: $"+str('{:.2f}'.format(round(20*sugPrice*.91,2)))+" (3)")
        print ("................RETURN TO MARKET MENU (R)")
        print ("")
        command12 = (input("ENTER COMMAND HERE: ")).upper()
        while command12 != "1" and command12 != "2" and command12 != "3" and command12 != "R":
            command12 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command12 != "R":
            while True:
                try:
                    sugAmount = int(input("PLEASE ENTER # OF UNITS TO PURCHASE: "))
                    if command12 == "1":
                        while sugAmount*round(sugPrice,2) > cash or sugAmount<0: 
                            while sugAmount*round(sugPrice,2) > cash: 
                                sugAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while sugAmount < 0:
                                sugAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command12 == "2":
                        while sugAmount*round(5*sugPrice*.98,2) > cash or sugAmount<0: 
                            while sugAmount*round(5*sugPrice*.98,2) > 0:
                                sugAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while sugAmount<0:
                                sugAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command12 == "3":
                        while sugAmount*round(20*sugPrice*.91,2) > cash or sugAmount<0: 
                            while sugAmount*round(20*sugPrice*.91,2) >cash: 
                                sugAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while sugAmount<0:
                                sugAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command12 == "1":
                        sugar += sugAmount
                        cash -= sugAmount*round(sugPrice,2)
                    if command12 == "2":
                        sugar += sugAmount*5
                        cash -= sugAmount*round(5*sugPrice*.98,2)
                    if command12 == "3":
                        sugar += sugAmount*20
                        cash -= sugAmount*round(20*sugPrice*.91,2)
                    break
                except ValueError:
                    print ("PLEASE ENTER INTEGER!")


def cupShop ():
    command13 = ""
    global cash, cups
    while command13 != "R":
        clear_output(wait=True)
        time.sleep(.1)
        print ("LEMONS:"+ str(lemons)+" SUGAR:"+ str('{:.1f}'.format(round(sugar,1)))+
               "kg"+ " CUPS:"+ str(cups)+ ' CASH:$' +str('{:.2f}'.format(round(cash,2))))
        print ("_______________________________________")
        print ("_______________CUP STORE_______________")
        print ("........MARKET PRICE OF 1 CUP: $"+str('{:.2f}'.format(cupPrice))+" (1)")
        print (".......MARKET PRICE OF 5 CUPS: $"+str('{:.2f}'.format(round(5*cupPrice*.97,2)))+" (2)")
        print ("......MARKET PRICE OF 20 CUPS: $"+str('{:.2f}'.format(round(20*cupPrice*.92,2)))+" (3)")
        print ("...............RETURN TO MARKET MENU (R)")
        print ("")
        command13 = (input("ENTER COMMAND HERE: ")).upper()
        while command13 != "1" and command13 != "2" and command13 != "3" and command13 != "R":
            command13 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command13 != "R":
            while True:
                try:
                    cupAmount = int(input("PLEASE ENTER # OF UNITS TO PURCHASE: "))
                    if command13 == "1":
                        while cupAmount*cupPrice > cash or cupAmount<0:
                            while cupAmount*cupPrice > cash:
                                cupAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while cupAmount < 0:
                                cupAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: "))
                    if command13 == "2":
                        while round(cupAmount*5*cupPrice*.97,2) > cash or cupAmount<0: 
                            while round(cupAmount*5*cupPrice*.97,2) > cash:
                                cupAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while cupAmount<0:
                                cupAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: ")) 
                    if command13 == "3":
                        while round(cupAmount*20*cupPrice*.92,2) > cash or cupAmount<0:
                            while round(cupAmount*20*cupPrice*.92,2) >cash:
                                cupAmount = int(input("PLEASE ENTER # UNITS YOU CAN AFFORD:"))
                            while cupAmount<0:
                                cupAmount = int(input("PLEASE ENTER A POSITIVE INTEGER: ")) 
                    if command13 == "1":
                        cups += cupAmount
                        cash -= cupAmount*cupPrice
                    if command13 == "2":
                        cups += cupAmount*5
                        cash -= cupAmount*round(5*cupPrice*.97,2)
                    if command13 == "3":
                        cups += cupAmount*20
                        cash -= cupAmount*round(20*cupPrice*.92,2)
                    break
                except ValueError:
                    print ("PLEASE ENTER INTEGER!")

def bankMenu ():
    command14 = ""
    global cash, account, loan, loanAmount, loanDays, maxcash, maxcashsav, maxAccount
    spaceCount2 = 22 - int(len(str('{:.1f}'.format(account))))
    space2 = "."*spaceCount2
    spaceCount3 = 26 - int(len(str('{:.2f}'.format(loanAmount))))
    space3 = "."*spaceCount3
    spaceCount4 = 3 - len(str(loanDays))
    space4 = "."*spaceCount4
    while command14 != "R":
        clear_output(wait=True)
        time.sleep(.1)
        if cash > maxcash:
            maxcash = cash
        if (cash + account) > maxcashsav:
            maxcashsav = (cash+account)
        print ("SAVINGS DAILY INTEREST RATE: "+ str(100*savingsInterest)+"%"+"\nLOAN DAILY INTEREST RATE: "+ str(100*loansInterest)+"%"+
             '\nCASH:$' +str('{:.2f}'.format(round(cash,2))))
        print ("______________________________________")
        print ("______________LEMON BANK______________")
        print ("ACCOUNT BALANCE"+space2+str('{:.2f}'.format(account)))
        print ("DEBT BALANCE"+space3+str('{:.2f}'.format(loanAmount)))
        print ("DAYS TO LOAN MATURITY.............."+space4+str(loanDays))
        print ("......................DEPOSIT CASH (1)")
        print (".....................WITHDRAW CASH (2)")
        print ("...............REQUEST 10 DAY LOAN (3)")
        print ("...............RETURN TO MAIN MENU (R)")
        print ("")
        command14 = (input("ENTER COMMAND HERE: ")).upper()
        while command14 != "1" and command14 != "2" and command14 != "3" and command14 != "R":
            command14 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command14 != "R":
            while True:
                try:
                    if command14 == "1":
                        deposit = float(input("PLEASE ENTER AMOUNT OF CASH TO DEPOSIT: "))
                        while deposit > cash or deposit<0:
                            while deposit > cash:
                                deposit = float(input("PLEASE ENTER AMOUNT EQUAL TO OR LESS THAN CASH:"))
                            while deposit < 0:
                                deposit = float(int(input("PLEASE ENTER A POSITIVE AMOUNT: ")))
                    if command14 == "1":
                        account += round(deposit,2)
                        cash -= round(deposit,2)
                        if account > maxAccount:
                            macAccount = account
                    if command14 == "2":
                        if account >= 0:
                            withdraw = float(input("PLEASE ENTER AMOUNT OF CASH TO WITHDRAW: "))
                            while withdraw > account or withdraw<0:
                                while withdraw > account:
                                    withdraw = float(input("PLEASE ENTER AMOUNT EQUAL TO OR LESS THAN BALANCE:"))
                                while withdraw < 0:
                                    withdraw = float(int(input("PLEASE ENTER A POSITIVE AMOUNT: ")))
                            if command14 == "2":
                                account -= round(withdraw,2)
                                cash += round(withdraw,2)
                        else:
                            print ("")
                            print (colored("ACCOUNT BALANCE NEGATIVE",'red'))
                            print (colored("UNABLE TO WITHDRAW..",'red'))
                            unwith = "1"
                            while unwith != "":
                                unwith = input("PRESS ENTER:")
                    if command14 == "3":
                        if loan == 1:
                            print ("")
                            print (colored("REQUEST DENIED!","red"))
                            print (colored("THERE EXISTS AN OUTSTANDING LOAN", "red"))
                            outloan = "1"
                            while outloan != "":
                                outloan = input("PRESS ENTER:")
                        if loan == 0:
                            request = round(float(input("PLEASE ENTER REQUESTED LOAN AMOUNT:")),2)
                            if request >= maxAccount*0.75*random.uniform(0.85,1.15):
                                print ("")
                                print(colored("REQUEST DENIED!",'red'))
                                print(colored("NOT ENOUGH CREDIT...",'red'))
                                nocred = "1"
                                while nocred != "":
                                    nocred = input("PRESS ENTER:")
                            elif request <= 0:
                                print ("")
                                printc (red("UNABLE TO PROCESS NEGATIVE VALUE"))
                                negVal = "1"
                                while negVal != "":
                                    negVal = input("PRESS ENTER:")
                            else:
                                loanAmount = request
                                loan = 1
                                loanDays = 10
                                account +=loanAmount
                                print ("\nREQUEST APROVED! \nFUNDS TRANSFERED TO ACCOUNT")
                                print ("REPAYMENT DUE IN 10 DAYS")
                                reqapproved = "1"
                                while reqapproved != "":
                                    reqapproved = input("PRESS ENTER:")
                    break
                except ValueError:
                    print ("PLEASE ENTER NUMBER!")
            spaceCount2 = 22 - int(len(str('{:.1f}'.format(account))))
            space2 = "."*spaceCount2
            spaceCount3 = 26 - int(len(str('{:.2f}'.format(loanAmount))))
            space3 = "."*spaceCount3
            spaceCount4 = 3 - len(str(loanDays))
            space4 = "."*spaceCount4

def departmentStore():
    global cash, locations, canopies, coolerPrice, canopyPrice, standPrice, coolers, wages
    command15 = ""
    spaceCount5 = 10 - int(len(str('{:.2f}'.format(standPrice))))
    space5 = "."*spaceCount5
    while command15 != "R":
        clear_output(wait=True)
        time.sleep(.1)
        print ("LOCATIONS:"+ str(locations)+ "  COOLERS:"+ str(coolers)+"  CANOPIES:"+ str(canopies) +
                "  CASH:$" +str('{:.2f}'.format(round(cash,2))))
        print ("________________________________________")
        print ("____________DEPARTMENT STORE____________")
        print ("LEMON COOLER.................. $"+str('{:.2f}'.format(coolerPrice)+" (1)"))
        print ("LEMON STAND CANOPY............ $"+str('{:.2f}'.format(canopyPrice)+" (2)"))
        print ("ADDITIONAL LEMON STAND...."+space5+"$"+str('{:.2f}'.format(standPrice)+" (3)"))
        print ("................RETURN TO MARKET MENU (R)")
        print ("")
        command15 = (input ("ENTER COMMAND HERE: ")).upper()
        while command15 != "1" and command15 != "2" and command15 != "3" and command15 != "R":
            command15 = (input("PLEASE ENTER VALID COMMAND: ")).upper()
        if command15 == "1":
            if coolers < locations and cash >= coolerPrice:
                confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    cash -= coolerPrice
                    coolers += 1
            elif cash < coolerPrice:
                print(colored("NOT ENOUGH CASH FOR PURCHASE",'red'))
                noCash = "1"
                while noCash != "":
                    noCash = input ("PRESS ENTER:")
            else:
                print ("")
                print(colored("YOU HAVE A COOLER FOR EVERY LOCATION",'red'))
                haveCooler = "1"
                while haveCooler != "":
                    haveCooler = input ("PRESS ENTER:")
        if command15 == "2":
            if canopies < locations and cash >= canopyPrice:
                confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    cash -= canopyPrice
                    canopies += 1
            elif canopies == locations:
                print ("")
                print(colored("YOU HAVE A CANOPY FOR EVERY LOCATION",'red'))
                haveCanopy = "1"
                while haveCanopy != "":
                    haveCanopy = input ("PRESS ENTER:")
            else:
                print ("")
                print(colored("NOT ENOUGH CASH FOR PURCHASE",'red'))
                noCash = "1"
                while noCash != "":
                    noCash = input ("PRESS ENTER:")
        if command15 == "3":
            if cash >= standPrice:
                confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                while confirm != "Y" and confirm != "N":
                    confirm = input("PLEASE CONFIRM PURCHASE (Y/N):").upper()
                if confirm == "Y":
                    cash -= standPrice
                    locations += 1
                    wages += 5
            else: 
                print(colored("NOT ENOUGH CASH FOR PURCHASE",'red'))
                noCash = "1"
                while noCash != "":
                    noCash = input ("PRESS ENTER:")
        spaceCount5 = 10 - int(len(str('{:.2f}'.format(standPrice))))
        space5 = "."*spaceCount5
        
def game():
    #declare all global variables 
    global cash, lemons, sugar, cups, day, locations, account, maxAccount, lemPrice
    global sugPrice, cupPrice, oldDemand, rotFact, loan, loanAmount, loanDays, loansInterest
    global savingsInterest, coolers, canopies, coolerPrice, canopyPrice, standPrice, wages
    global marketingEffect, radioPrice, searchEnginePrice, socialMediaPrice, billboardPrice
    global radioCampaignDays, searchEngineCampaignDays, socialMediaCampaignDays
    global billboardCampaignDays, maxcash, maxcashsav
    #initialize values of global variables 
    cash = 100
    maxcash = cash
    maxcashsav = cash
    marketingEffect = 0
    account = 0.00
    maxAccount = account
    lemons = 0
    sugar = 0
    cups = 0
    day = 0
    locations = 1
    yestLemPrice = 0.65
    yestSugPrice = 1.25
    yestCupPrice = 0.23
    oldDemand = 4
    rotFact = 1
    rent = 10
    yestCash = 100
    loan = 0
    loanAmount = 0.00
    savingsInterest = 0.02
    loansInterest = 0.03
    loanDays = 0
    coolers = 0
    canopies = 0
    wages = 0
    searchEngineCampaignDays = 0
    socialMediaCampaignDays = 0
    billboardCampaignDays = 0
    radioCampaignDays = 0
    print ("")
    print ("WELCOME TO LEMONADE EMPIRE!")
    name = (input("PLEASE ENTER YOUR NAME: ")).upper()
    while len(name)>7 or len(name)==0:
        if len(name)>7:
            name = (input("PLEASE ENTER SHORTER NAME:")).upper()
        else:
            name = (input("PLEASE ENTER YOUR NAME:")).upper()
    clear_output(wait=True)
    print("TIME TO BUILD "+name+"'S "+"LEMONADE EMPIRE!")
    print(" ")
    print("________________________________")
    print("___________GUIDELINES___________")
    print("1. DON'T RUN OUT OF CASH")
    print("2. FIVE LEMONS + HALF KG SUGAR = ONE JUG LEMONADE")
    print("3. ONE JUG = EIGHT CUPS OF LEMONADE")
    print("4. HIGH-SCORES ARE BASED ON MAXIMUM $\n")
    understood = "1"
    while understood != "":
        understood = input("PRESS ENTER IF UNDERSTOOD:" )
    spacecount = 7- len(name)
    space = " "*spacecount
    while round(cash,2) > 0:
        day += 1
        # daily change in sugar and lemon prices
        lemChange = random.uniform(-0.08,0.11)
        sugChange = random.uniform(-0.07,0.10)
        cupChange = random.uniform(-0.03,0.04)
        # set today's sugar and lemon prices
        lemPrice = max(0.05,round(yestLemPrice + lemChange,2))
        sugPrice = max(0.05,round(yestSugPrice + sugChange,2))
        cupPrice = max(0.05,round(yestCupPrice + cupChange,2))
        # set (new) yesterday price of commodities 
        yestLemPrice = lemPrice
        yestSugPrice = sugPrice
        yestCupPrice = cupPrice
        # set price of department store items
        coolerPrice = 35 + random.randint(-10,10)
        canopyPrice = 50 + random.randint(-15,15)
        standPrice = 115 + random.randint(-30,30)
        #set/reset marketing prices
        radioPrice = 235 + random.randint(-15,75)
        searchEnginePrice = 30 + random.randint(-5,15)
        socialMediaPrice = 55 + random.randint (-10,25)
        billboardPrice = 650 + random.randint(-25,85)
        # allow user to make purchases/changes for the next day (nested menus) 
        mainMenu()
        # reduce days left of marketing campaigns
        if searchEngineCampaignDays > 0:
            searchEngineCampaignDays -= 1
        if socialMediaCampaignDays > 0:
            socialMediaCampaignDays -= 1
        if radioCampaignDays > 0:
            radioCampaignDays -= 1
        if billboardCampaignDays > 0:
            billboardCampaignDays -= 1
        # set up random integer to maybe increase rent
        rentHike = random.randint(min(day,50), 70)
        # set up random integer to maybe get robbed
        robbed = random.randint(1,25)
        #set up random integer to rain
        rain = random.randint(1,15)
        clear_output(wait=True)
        print(""+"\n")
        print("SUNRISE.....\n")
        print("         |")
        print("     \       /           O")            
        print("       .-=-.         ___\|/___")
        print(" ---  /     \  ---  |"+name+"'S"+space+"|")
        print("------=======-------|LEMONADE |--")
        print (""+"\n")
        print ("A NEW DAY HAS BEGUN")
        # set price of lemonade
        while True:
            try:
                salePrice = round(float(((input("PLEASE ENTER SALE PRICE PER CUP IN $: ")))),2)
                while salePrice < 0:
                    salePrice = round(float(((input("PLEASE ENTER SALE PRICE GREATER THAN 0: ")))),2)
                break
            except ValueError:
                print ("")
                print ("PLEASE ENTER VALUE IN DOLLARS AND CENTS!")
        openShop = "close"
        while openShop != "":
            openShop = input("PRESS ENTER TO OPEN SHOP:")
        print ("\nSIMULATING...")
        time.sleep(2)
        # 2 demand functions to create demand input
        if (5.85-salePrice)<0:
            salesDemand = 0
        else:
            salesDemand = int(1.45*(5.85-salePrice)**2)
        demand = int(salesDemand*random.uniform(.72,1.45)*locations*random.uniform(.85,1.2)*(1+marketingEffect/50))
        print("")
        print ("DEMAND TODAY:", demand)
        # calculates max number of jugs that can be made
        maxJugs = (min(round(lemons/5-0.4999),round(sugar/.5-0.4999)))
        # calculates actual sold based on resources and demand
        cupsSold = min(min(maxJugs*8,demand),cups)
        # calculates jugs made
        jugsMade = round(cupsSold/8+0.499)
        # reduce lemon stock by number of lemons consumed and reduce cash
        lemons -= jugsMade*5
        sugar -= jugsMade*0.5
        cups -= cupsSold
        cash += cupsSold*salePrice
        sales = cupsSold*salePrice
        # display cups sold, sale revenue and profit on sales
        print ("CUPS SOLD:",cupsSold)
        print ("SALES REVENUE: $"+str(round(sales,2)))
        # left over lemons calculation (to rot) 
        if lemons > 0:
            rotFact = 0.5 - 0.4*(coolers/locations)
            leftLemons = int(round((lemons-0.001)*rotFact))
        else:
            leftLemons = 0
        print ("LEFTOVER LEMONS GONE BAD: "+str(leftLemons))
        lemons -= leftLemons
        # rent collection
        if rentHike == 50:
            print(colored("...RENT(S) INCREASED BY $5!...",'red'))
            rent += 5
        if locations == 1:
            print ("LANDLORD COLLECTED RENT: $"+str(rent*locations))
        else:
            print ("LANDLORDS COLLECTED RENT: $"+str(rent*locations))
        cash -= rent*locations
        # display cost of wages
        if wages > 0:
            print ("COST OF EMPLOYEE WAGES $" +str(wages))
            cash -= wages
        # net cash calculation
        netCash = round(float((cash-yestCash)),2)
        yestCash = cash
        print ("------------------------------")
        print ("NET CASH TODAY: $"+str(netCash))
        print ("")
        # check if robbed
        if robbed == 12:
            amountRobbed = int(((1-random.uniform(0,.89))*cash))
            print(colored("YOU WERE ROBBED!... SOMEONE STOLE $" + str(amountRobbed),'red'))
            cash -= int(amountRobbed)
            print("")
        time.sleep(0.5)
        if account > 0:
            account = account*(1+savingsInterest)
        # check if rained
        if rain == 12:
            sugarLost = str(round(sugar*(0.5 - 0.5*(canopies/locations)),2))
            print(colored("IT RAINED!... " + sugarLost +"kg"+ " SUGAR MELTED",'red'))
            sugar -= round(float(sugarLost),2)
            print ("")
        # Loan changes and checks
        loanAmount = loanAmount*(1+loansInterest)
        if loanDays > 0:
            loanDays -= 1
        if loanDays == 0 and loan == 1:
            loan = 0
            print (colored("LOAN REPAYMENT DUE!",'red'))
            print(colored("DEBT + INTEREST WITHDRAWN FROM ACCOUNT",'red'))
            account -= loanAmount
            loanAmount = 0
            time.sleep(0.5)
        understood2 = "1"
        while understood2 != "":
            understood2 = input("PRESS ENTER TO RETURN TO MAIN MENU:" )
        if cash > maxcash:
            maxcash = cash
        if (cash + account) > maxcashsav:
            maxcashsav = (cash+account)
    clear_output()
    print (colored(".....................GAME OVER......................",'red'))
    print (colored("...YOUR EMPIRE CAME CRUMBLING DOWN AFTER "+ str(day)+ " DAY(S)...",'red'))
    time.sleep(2)
    with open('drive/My Drive/Lemonade Empire/AllGames.csv', 'a') as file:
        writer = csv.writer(file)
        writer.writerow([name.title(),date.today(),maxcash,maxcashsav,day])
    HSDF = pd.read_csv('drive/My Drive/Lemonade Empire/HighScores.csv')
    HSDF = HSDF.dropna()
    for x in range(len(HSDF)):
        if maxcashsav > HSDF.iloc[x,3]:
            HSDF.iloc[x,3] = maxcashsav
            HSDF.iloc[x,1] = name.title()
            HSDF.iloc[x,2] = date.today()
            HSDF.iloc[x,4] = day
            break
    with open('drive/My Drive/Lemonade Empire/HighScores.csv', 'w', newline='') as file:
            writer = csv.writer(file)
            HSDF_list = HSDF.values.tolist()
            writer.writerow(["Rank", '  Name ','  Date   ',' Max ($)','   Days Lasted'])
            for x in range(len(HSDF)):
                sublist = HSDF_list[x]
                a = sublist[0]
                b = (sublist[1]).title()
                c = sublist[2]
                d = round(sublist[3],2)
                e = sublist[4]
                writer.writerow([a,b,c,d,e])
    print ("\n____________________________________________________")
    print ("_____________________HIGH-SCORES____________________")
    print (HSDF.to_string(index=False))

# %%
again = "Y"
while again == "Y":
    game()
    print("")
    again = (input("PLAY AGAIN? (Y/N)")).upper()
    while again != "Y" and again != "N":
        again = (input("PLEASE ENTER 'Y' OR 'N'")).upper()
    print("")
